# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression

# %%
# Cargar archivos

df_player_data = pd.read_csv('res/player_data.csv')
df_players = pd.read_csv('res/players.csv')
df_season_stats = pd.read_csv('res/Seasons_Stats.csv')

# %%
df_players.head()
# Out:
#    Unnamed: 0           Player  height  weight  \
# 0           0  Curly Armstrong   180.0    77.0
# 1           1     Cliff Barker   188.0    83.0
# 2           2    Leo Barnhorst   193.0    86.0
# 3           3       Ed Bartels   196.0    88.0
# 4           4      Ralph Beard   178.0    79.0
#
#                            collage    born   birth_city birth_state
# 0               Indiana University  1918.0          NaN         NaN
# 1           University of Kentucky  1921.0     Yorktown     Indiana
# 2         University of Notre Dame  1924.0          NaN         NaN
# 3  North Carolina State University  1925.0          NaN         NaN
# 4           University of Kentucky  1927.0  Hardinsburg    Kentucky

# %%
df_season_stats.head()
# Out:
#    Unnamed: 0    Year           Player  Pos   Age   Tm     G  GS  MP  PER  \
# 0           0  1950.0  Curly Armstrong  G-F  31.0  FTW  63.0 NaN NaN  NaN
# 1           1  1950.0     Cliff Barker   SG  29.0  INO  49.0 NaN NaN  NaN
# 2           2  1950.0    Leo Barnhorst   SF  25.0  CHS  67.0 NaN NaN  NaN
# 3           3  1950.0       Ed Bartels    F  24.0  TOT  15.0 NaN NaN  NaN
# 4           4  1950.0       Ed Bartels    F  24.0  DNN  13.0 NaN NaN  NaN
#
#    ...    FT%  ORB  DRB  TRB    AST  STL  BLK  TOV     PF    PTS
# 0  ...  0.705  NaN  NaN  NaN  176.0  NaN  NaN  NaN  217.0  458.0
# 1  ...  0.708  NaN  NaN  NaN  109.0  NaN  NaN  NaN   99.0  279.0
# 2  ...  0.698  NaN  NaN  NaN  140.0  NaN  NaN  NaN  192.0  438.0
# 3  ...  0.559  NaN  NaN  NaN   20.0  NaN  NaN  NaN   29.0   63.0
# 4  ...  0.548  NaN  NaN  NaN   20.0  NaN  NaN  NaN   27.0   59.0
#
# [5 rows x 53 columns]

# %%
df_player_data.head()
# Out:
#                   name  year_start  year_end position height  weight  \
# 0       Alaa Abdelnaby        1991      1995      F-C   6-10   240.0
# 1      Zaid Abdul-Aziz        1969      1978      C-F    6-9   235.0
# 2  Kareem Abdul-Jabbar        1970      1989        C    7-2   225.0
# 3   Mahmoud Abdul-Rauf        1991      2001        G    6-1   162.0
# 4    Tariq Abdul-Wahad        1998      2003        F    6-6   223.0
#
#          birth_date                                college
# 0     June 24, 1968                        Duke University
# 1     April 7, 1946                  Iowa State University
# 2    April 16, 1947  University of California, Los Angeles
# 3     March 9, 1969             Louisiana State University
# 4  November 3, 1974              San Jose State University

# %%
df_players.shape
# Out:
# (3922, 8)

# %%
df_season_stats.shape
# Out:
# (24691, 53)

# %%
df_player_data.shape
# Out:
# (4550, 8)

# %%
# Renombrar la columna name por Player.

df_data = df_player_data.rename(columns = {'name':'Player'})
df_data
# Out:
#                    Player  year_start  year_end position height  weight  \
# 0          Alaa Abdelnaby        1991      1995      F-C   6-10   240.0
# 1         Zaid Abdul-Aziz        1969      1978      C-F    6-9   235.0
# 2     Kareem Abdul-Jabbar        1970      1989        C    7-2   225.0
# 3      Mahmoud Abdul-Rauf        1991      2001        G    6-1   162.0
# 4       Tariq Abdul-Wahad        1998      2003        F    6-6   223.0
# ...                   ...         ...       ...      ...    ...     ...
# 4545           Ante Zizic        2018      2018      F-C   6-11   250.0
# 4546             Jim Zoet        1983      1983        C    7-1   240.0
# 4547            Bill Zopf        1971      1971        G    6-1   170.0
# 4548          Ivica Zubac        2017      2018        C    7-1   265.0
# 4549           Matt Zunic        1949      1949      G-F    6-3   195.0
#
#              birth_date                                college
# ...

# %%
# Unión de los tres Dataframe por Player.

df_ply_data = pd.merge(df_players, df_data, on= 'Player')
df_info_all = pd.merge(df_ply_data, df_season_stats, on='Player')
df_info_all.head()
# Out:
#    Unnamed: 0_x           Player  height_x  weight_x                 collage  \
# 0             0  Curly Armstrong     180.0      77.0      Indiana University
# 1             0  Curly Armstrong     180.0      77.0      Indiana University
# 2             1     Cliff Barker     188.0      83.0  University of Kentucky
# 3             1     Cliff Barker     188.0      83.0  University of Kentucky
# 4             1     Cliff Barker     188.0      83.0  University of Kentucky
#
#      born birth_city birth_state  year_start  year_end  ...    FT% ORB  DRB  \
# 0  1918.0        NaN         NaN        1949      1951  ...  0.705 NaN  NaN
# 1  1918.0        NaN         NaN        1949      1951  ...  0.644 NaN  NaN
# 2  1921.0   Yorktown     Indiana        1950      1952  ...  0.708 NaN  NaN
# 3  1921.0   Yorktown     Indiana        1950      1952  ...  0.649 NaN  NaN
# 4  1921.0   Yorktown     Indiana        1950      1952  ...  0.588 NaN  NaN
#
#      TRB    AST  STL  BLK TOV     PF    PTS
# ...

# %%
df_info_all.columns
# Out:
# Index(['Unnamed: 0_x', 'Player', 'height_x', 'weight_x', 'collage', 'born',
#        'birth_city', 'birth_state', 'year_start', 'year_end', 'position',
#        'height_y', 'weight_y', 'birth_date', 'college', 'Unnamed: 0_y', 'Year',
#        'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'PER', 'TS%', '3PAr', 'FTr',
#        'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'blanl',
#        'OWS', 'DWS', 'WS', 'WS/48', 'blank2', 'OBPM', 'DBPM', 'BPM', 'VORP',
#        'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%',
#        'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV',
#        'PF', 'PTS'],
#       dtype='object')

# %%
df_info_all.shape
# Out:
# (23468, 67)

# %% [markdown]
# LIMPIEZA DATA FRAME

# %%
# Eliminar los NaN del dataframe

df_clean = df_info_all.fillna(0)

# %%
# Eliminando las columnas height_y(pies) y weight_y(libras)

df_clean = df_clean.drop(['height_y','weight_y'], axis=1)

# %%
# Eliminando columnas no necesarias para la investigación

df_clean = df_clean.drop(['birth_city','birth_state','collage','born','Unnamed: 0_y','Unnamed: 0_x'], axis=1)

# %%
df_clean=df_clean.drop(['college'], axis=1)

# %%
# Columnas con las que se trabajará

df_clean.columns
# Out:
# Index(['Player', 'height_x', 'weight_x', 'year_start', 'year_end', 'position',
#        'birth_date', 'Year', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'PER', 'TS%',
#        '3PAr', 'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%',
#        'USG%', 'blanl', 'OWS', 'DWS', 'WS', 'WS/48', 'blank2', 'OBPM', 'DBPM',
#        'BPM', 'VORP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA',
#        '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL',
#        'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
# DATAFRAME LIMPIO Y LISTO PARA TRABAJAR

df_clean
# Out:
#                   Player  height_x  weight_x  year_start  year_end position  \
# 0        Curly Armstrong     180.0      77.0        1949      1951      G-F
# 1        Curly Armstrong     180.0      77.0        1949      1951      G-F
# 2           Cliff Barker     188.0      83.0        1950      1952        G
# 3           Cliff Barker     188.0      83.0        1950      1952        G
# 4           Cliff Barker     188.0      83.0        1950      1952        G
# ...                  ...       ...       ...         ...       ...      ...
# 23463      Troy Williams     198.0      97.0        2017      2018        F
# 23464       Kyle Wiltjer     208.0     108.0        2017      2017        F
# 23465  Stephen Zimmerman     213.0     108.0        2017      2017        C
# 23466        Paul Zipser     203.0      97.0        2017      2018      G-F
# 23467        Ivica Zubac     216.0     120.0        2017      2018        C
#
# ...

# %%
# Extraer DataFrame limpio a csv

#df_clean.to_csv('data_clean.csv')

# %%
porcentaje_3P = df_clean['3P%']
porcentaje_3P
# Out:
# 0        0.000
# 1        0.000
# 2        0.000
# 3        0.000
# 4        0.000
#          ...
# 23463    0.381
# 23464    0.308
# 23465    0.000
# 23466    0.333
# 23467    0.000
# Name: 3P%, Length: 23468, dtype: float64

# %%
año_temportadas = df_clean['Year'].unique()
sorted(año_temportadas)
# Out:
# [1950.0,
#  1951.0,
#  1952.0,
#  1953.0,
#  1954.0,
#  1955.0,
#  1956.0,
#  1957.0,
#  1958.0,
#  1959.0,
#  1960.0,
#  1961.0,
#  1962.0,
#  1963.0,
#  1964.0,
#  1965.0,
#  1966.0,
#  1967.0,
#  1968.0,
#  1969.0,
#  1970.0,
#  1971.0,
#  1972.0,
#  1973.0,
#  1974.0,
#  1975.0,
#  1976.0,
#  1977.0,
#  1978.0,
#  1979.0,
#  1980.0,
#  1981.0,
#  1982.0,
#  1983.0,
#  1984.0,
#  1985.0,
#  1986.0,
#  1987.0,
#  1988.0,
#  1989.0,
#  1990.0,
#  1991.0,
#  1992.0,
#  1993.0,
#  1994.0,
#  1995.0,
#  1996.0,
#  1997.0,
#  1998.0,
#  1999.0,
#  2000.0,
#  2001.0,
#  2002.0,
#  2003.0,
#  2004.0,
#  2005.0,
#  2006.0,
#  2007.0,
#  2008.0,
#  2009.0,
#  2010.0,
#  2011.0,
#  2012.0,
#  2013.0,
#  2014.0,
#  2015.0,
#  2016.0,
#  2017.0]

# %%
media_3P_año = df_clean.groupby('Year')['3P%'].mean()
media_3P_año
# Out:
# Year
# 1950.0    0.000000
# 1951.0    0.000000
# 1952.0    0.000000
# 1953.0    0.000000
# 1954.0    0.000000
#             ...
# 2013.0    0.234282
# 2014.0    0.243674
# 2015.0    0.250627
# 2016.0    0.267248
# 2017.0    0.278438
# Name: 3P%, Length: 68, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(15,8))
ax.bar ( x = año_temportadas, height = media_3P_año)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df_clean.loc[:,['Year','Player', '3P%']].max()
# Out:
# Year                  2017.0
# Player    Zydrunas Ilgauskas
# 3P%                      1.0
# dtype: object

# %%
year_2003 = df_clean[df_clean['Year']==2003]
porc_3p_2003 = year_2003.loc[:,['Player', '3P%']]
porc_3p_2003.max()
# Out:
# Player    Zydrunas Ilgauskas
# 3P%                      1.0
# dtype: object

# %%
df_clean_copy = df_clean.copy()
df_clean_copy.head()
# Out:
#             Player  height_x  weight_x  year_start  year_end position  \
# 0  Curly Armstrong     180.0      77.0        1949      1951      G-F
# 1  Curly Armstrong     180.0      77.0        1949      1951      G-F
# 2     Cliff Barker     188.0      83.0        1950      1952        G
# 3     Cliff Barker     188.0      83.0        1950      1952        G
# 4     Cliff Barker     188.0      83.0        1950      1952        G
#
#          birth_date    Year  Pos   Age  ...    FT%  ORB  DRB    TRB    AST  \
# 0  November 1, 1918  1950.0  G-F  31.0  ...  0.705  0.0  0.0    0.0  176.0
# 1  November 1, 1918  1951.0  G-F  32.0  ...  0.644  0.0  0.0   89.0   77.0
# 2  January 15, 1921  1950.0   SG  29.0  ...  0.708  0.0  0.0    0.0  109.0
# 3  January 15, 1921  1951.0   SG  30.0  ...  0.649  0.0  0.0  100.0  115.0
# 4  January 15, 1921  1952.0   SG  31.0  ...  0.588  0.0  0.0   81.0   70.0
#
#    STL  BLK  TOV     PF    PTS
# 0  0.0  0.0  0.0  217.0  458.0
# ...

# %%
df_clean_P = df_clean_copy[df_clean_copy['position'] == 'C']
df_clean_P
# Out:
#                   Player  height_x  weight_x  year_start  year_end position  \
# 37         Harry Boykoff     208.0     102.0        1950      1951        C
# 38         Harry Boykoff     208.0     102.0        1950      1951        C
# 39         Harry Boykoff     208.0     102.0        1950      1951        C
# 40         Harry Boykoff     208.0     102.0        1950      1951        C
# 67            Jim Browne     208.0     106.0        1949      1950        C
# ...                  ...       ...       ...         ...       ...      ...
# 23450        Edy Tavares     211.0     115.0        2016      2017        C
# 23451        Edy Tavares     211.0     115.0        2016      2017        C
# 23453         Mike Tobey     213.0     117.0        2017      2017        C
# 23465  Stephen Zimmerman     213.0     108.0        2017      2017        C
# 23467        Ivica Zubac     216.0     120.0        2017      2018        C
#
# ...

# %%
# información Temporada/año y la media 3P%


tabla_media_triples_P = df_clean_P.groupby('Year')['3P%'].mean()
tabla_media_triples_P
# Out:
# Year
# 1950.0    0.000000
# 1951.0    0.000000
# 1952.0    0.000000
# 1953.0    0.000000
# 1954.0    0.000000
#             ...
# 2013.0    0.089829
# 2014.0    0.062740
# 2015.0    0.103279
# 2016.0    0.087408
# 2017.0    0.075625
# Name: 3P%, Length: 68, dtype: float64

# %%
# Información por posición del jugador (P) y la media 3P%

tabla_media_pos_triple = df_clean_copy.groupby('position')['3P%'].mean().reset_index()
tabla_media_pos_triple
# Out:
#   position       3P%
# 0        0  0.000000
# 1        C  0.050014
# 2      C-F  0.056331
# 3        F  0.154889
# 4      F-C  0.087107
# 5      F-G  0.185413
# 6        G  0.230998
# 7      G-F  0.204830

# %%
# Crea un nuevo DataFrame con el nombre de la columna y los valores de la media
tabla_resultado_P = pd.DataFrame({
    'Year': tabla_media_triples_P.index,
    '3P%': tabla_media_triples_P.values
})
print(tabla_resultado_P)
tabla_resultado_P.index
# Out:
#       Year       3P%
# 0   1950.0  0.000000
# 1   1951.0  0.000000
# 2   1952.0  0.000000
# 3   1953.0  0.000000
# 4   1954.0  0.000000
# ..     ...       ...
# 63  2013.0  0.089829
# 64  2014.0  0.062740
# 65  2015.0  0.103279
# 66  2016.0  0.087408
# 67  2017.0  0.075625
#
# [68 rows x 2 columns]
# RangeIndex(start=0, stop=68, step=1)

# %% [markdown]
# ### Regresión Lineal

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import numpy as np
import matplotlib.pyplot as plt

# Supongamos que df es tu DataFrame con las columnas 'Años' y 'PorcentajeTriples'

# Dividir el conjunto de datos en entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(tabla_resultado_P['Year'].values.reshape(-1, 1), tabla_resultado_P['3P%'].values, test_size=0.2, random_state=42)

# Crear un modelo de regresión lineal
model = LinearRegression()

# Entrenar el modelo
model.fit(X_train, y_train)

# Realizar predicciones
y_pred = model.predict(X_test)

# Evaluar el modelo
mse = mean_squared_error(y_test, y_pred)
print(f'Mean Squared Error: {mse}')

# Predecir para los próximos 5 años
future_years = np.arange(2018, 2023).reshape(-1, 1)
future_predictions = model.predict(future_years)

# Graficar resultados
plt.scatter(tabla_resultado_P['Year'], tabla_resultado_P['3P%'], label='Datos históricos')
plt.plot(X_test, y_pred, color='red', label='Regresión lineal')
plt.scatter(future_years, future_predictions, color='green', label='Predicciones futuras')
plt.xlabel('Year')
plt.ylabel('3P%')
plt.legend()
plt.show()
# Out:
# Mean Squared Error: 0.0015694278312736645

# %% [markdown]
# ### Regresión Polinómica

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline

# Crear un modelo de regresión polinómica de grado 2
model = make_pipeline(PolynomialFeatures(degree=2), LinearRegression())

# Entrenar el modelo
model.fit(X_train, y_train)

# Realizar predicciones
y_pred_poly = model.predict(X_test)

# Evaluar el modelo
mse_poly = mean_squared_error(y_test, y_pred_poly)
print(f'Mean Squared Error (Polinómico): {mse_poly}')

# Predecir para los próximos 5 años
future_predictions_poly = model.predict(future_years)

# Graficar resultados
plt.scatter(tabla_resultado_P['Year'], tabla_resultado_P['3P%'], label='Datos históricos')
plt.scatter(future_years, future_predictions_poly, color='purple', label='Predicciones futuras (Polinómico)')
plt.xlabel('Year')
plt.ylabel('3P%')
plt.legend()
plt.show()
# Out:
# Mean Squared Error (Polinómico): 0.001570338860730084

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import numpy as np
import matplotlib.pyplot as plt

# Supongamos que df es tu DataFrame con las columnas 'Años' y 'PorcentajeTriples'

# Dividir el conjunto de datos en entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(tabla_resultado_P['Year'].values.reshape(-1, 1), tabla_resultado_P['3P%'].values, test_size=0.2, random_state=42)

# Crear un modelo de Random Forest
model = RandomForestRegressor(n_estimators=100, random_state=42)

# Entrenar el modelo
model.fit(X_train, y_train)

# Realizar predicciones
y_pred = model.predict(X_test)

# Evaluar el modelo
mse = mean_squared_error(y_test, y_pred)
print(f'Mean Squared Error: {mse}')

# Predecir para los próximos 5 años
future_years = np.arange(2018, 2023).reshape(-1, 1)
future_predictions = model.predict(future_years)

# Graficar resultados
plt.scatter(tabla_resultado_P['Year'], tabla_resultado_P['3P%'], label='Datos históricos')
plt.scatter(future_years, future_predictions, color='green', label='Predicciones futuras (Random Forest)')
plt.xlabel('Year')
plt.ylabel('3P%')
plt.legend()
plt.show()
# Out:
# Mean Squared Error: 0.0011372661875283315

# %% [markdown]
# ### Método HOLT

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.holtwinters import ExponentialSmoothing

# Supongamos que df es tu DataFrame con las columnas 'Años' y 'PorcentajeTriples'
# Asegúrate de tener un índice temporal para trabajar con series temporales
tabla_resultado_P['Year'] = pd.to_datetime(tabla_resultado_P['Year'], format='%Y')
tabla_resultado_P.set_index('Year', inplace=True)

# Dividir el conjunto de datos en entrenamiento y prueba
train_data = tabla_resultado_P['3P%'].iloc[:-5]  # Tomar todos menos los últimos 5 años
test_data = tabla_resultado_P['3P%'].iloc[-5:]   # Tomar los últimos 5 años para la evaluación

# Crear y entrenar el modelo Holt
model = ExponentialSmoothing(train_data, trend='add', seasonal='add', seasonal_periods=12)
result = model.fit()

# Realizar predicciones
predictions = result.predict(start=test_data.index[0], end=test_data.index[-1])

# Graficar resultados
plt.plot(train_data.index, train_data, label='Datos de entrenamiento')
plt.plot(test_data.index, test_data, label='Datos de prueba', color='orange')
plt.plot(predictions.index, predictions, label='Predicciones', color='green')
plt.xlabel('Year')
plt.ylabel('3P%')
plt.legend()
plt.show()
# Out:
# c:\Users\Marc\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)

# %%
# Extrear csv para trabajarlo con Tableau

# Crear un DataFrame con las fechas y las predicciones
predictions_df = pd.DataFrame({'Date': predictions.index, '3P% Predicted': predictions.values})

# Exportar el DataFrame a un archivo CSV
predictions_df.to_csv('predicciones.csv', index=False)

# %% [markdown]
# ### Regresión polinómica de grado superior y SVR

# %%
# Crea un nuevo DataFrame con el nombre de la columna y los valores de la media
tabla_resultado_P = pd.DataFrame({
    'Year': tabla_media_triples_P.index,
    '3P%': tabla_media_triples_P.values
})
print(tabla_resultado_P)
tabla_resultado_P.index
# Out:
#       Year       3P%
# 0   1950.0  0.000000
# 1   1951.0  0.000000
# 2   1952.0  0.000000
# 3   1953.0  0.000000
# 4   1954.0  0.000000
# ..     ...       ...
# 63  2013.0  0.089829
# 64  2014.0  0.062740
# 65  2015.0  0.103279
# 66  2016.0  0.087408
# 67  2017.0  0.075625
#
# [68 rows x 2 columns]
# RangeIndex(start=0, stop=68, step=1)

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.svm import SVR

# Supongamos que df es tu DataFrame con las columnas 'Años' y 'PorcentajeTriples'

# Dividir el conjunto de datos en entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(tabla_resultado_P['Year'].values.reshape(-1, 1), tabla_resultado_P['3P%'].values, test_size=0.2, random_state=42)

# Regresión polinómica de grado superior
poly_degree = 3  # Ajusta según sea necesario
poly_features = PolynomialFeatures(degree=poly_degree)
X_poly_train = poly_features.fit_transform(X_train)
X_poly_test = poly_features.transform(X_test)

model_poly = LinearRegression()
model_poly.fit(X_poly_train, y_train)
y_pred_poly = model_poly.predict(X_poly_test)

# SVR
model_svr = SVR(kernel='rbf')
model_svr.fit(X_train, y_train)
y_pred_svr = model_svr.predict(X_test)

# Graficar resultados
plt.scatter(tabla_resultado_P['Year'], tabla_resultado_P['3P%'], label='Datos históricos')
plt.plot(X_test, y_pred_poly, color='red', label=f'Regresión Polinómica (Grado {poly_degree})')
plt.plot(X_test, y_pred_svr, color='blue', label='SVR')
plt.xlabel('Year')
plt.ylabel('3P%')
plt.legend()
plt.show()

# %%
# Supongamos que df es tu DataFrame con las columnas 'Años' y 'PorcentajeTriples'

# Extender el conjunto de datos hasta los próximos 5 años
future_years = np.arange(2018, 2023).reshape(-1, 1)

# Regresión polinómica de grado superior
future_poly_features = poly_features.transform(future_years)
future_predictions_poly = model_poly.predict(future_poly_features)

# SVR
future_predictions_svr = model_svr.predict(future_years)

# Graficar resultados
plt.scatter(tabla_resultado_P.index, tabla_resultado_P['3P%'], label='Datos históricos')
plt.plot(X_test, y_pred_poly, color='red', label=f'Regresión Polinómica (Grado {poly_degree})')
plt.plot(X_test, y_pred_svr, color='blue', label='SVR')
plt.scatter(future_years, future_predictions_poly, color='orange', label='Predicciones futuras (Polinómico)')
plt.scatter(future_years, future_predictions_svr, color='green', label='Predicciones futuras (SVR)')
plt.xlabel('Year')
plt.ylabel('3P%')
plt.legend()
plt.show()

# %% [markdown]
# ### Redes neuronales recurrentes (RNN) como Long Short-Term Memory (LSTM)

# %%
# Crea un nuevo DataFrame con el nombre de la columna y los valores de la media
tabla_resultado_P = pd.DataFrame({
    'Year': tabla_media_triples_P.index,
    '3P%': tabla_media_triples_P.values
})
print(tabla_resultado_P)
tabla_resultado_P.index
# Out:
#       Year       3P%
# 0   1950.0  0.000000
# 1   1951.0  0.000000
# 2   1952.0  0.000000
# 3   1953.0  0.000000
# 4   1954.0  0.000000
# ..     ...       ...
# 63  2013.0  0.089829
# 64  2014.0  0.062740
# 65  2015.0  0.103279
# 66  2016.0  0.087408
# 67  2017.0  0.075625
#
# [68 rows x 2 columns]
# RangeIndex(start=0, stop=68, step=1)

# %%
pip install tensorflow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

# Supongamos que df es tu DataFrame con las columnas 'Años' y 'PorcentajeTriples'
# Asegúrate de tener un índice temporal para trabajar con series temporales
tabla_resultado_P['Year'] = pd.to_datetime(tabla_resultado_P.index, format='%Y')
tabla_resultado_P.set_index('Year', inplace=True)

# Normalizar los datos
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(tabla_resultado_P[['3P%']])

# Crear conjuntos de entrenamiento y prueba
train_data = scaled_data[:-5]  # Tomar todos menos los últimos 5 años
test_data = scaled_data[-5:]   # Tomar los últimos 5 años para la evaluación

# Función para preparar los datos en secuencias para LSTM
def create_sequences(data, seq_length):
    sequences = []
    targets = []
    for i in range(len(data) - seq_length):
        seq = data[i:i + seq_length]
        label = data[i + seq_length]
        sequences.append(seq)
        targets.append(label)
    return np.array(sequences), np.array(targets)

# Definir la longitud de la secuencia
sequence_length = 3  # Ajusta según sea necesario

# Crear secuencias para entrenamiento y prueba
X_train, y_train = create_sequences(train_data, sequence_length)
X_test, y_test = create_sequences(test_data, sequence_length)

# Crear el modelo LSTM
model = Sequential()
model.add(LSTM(50, activation='relu', input_shape=(sequence_length, 1)))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

# Reshape los datos para que coincidan con la entrada de LSTM [samples, time steps, features]
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

# Entrenar el modelo
model.fit(X_train, y_train, epochs=100, verbose=1)

# Realizar predicciones
predictions = model.predict(X_test)

# Desnormalizar las predicciones y los datos de prueba
predictions = scaler.inverse_transform(predictions)
y_test = scaler.inverse_transform(y_test)

# Graficar resultados
plt.plot(tabla_resultado_P.index[:-5], tabla_resultado_P['3P%'][:-5], label='Datos de entrenamiento')
plt.plot(tabla_resultado_P.index[-5:], tabla_resultado_P['3P%'][-5:], label='Datos de prueba', color='orange')
plt.plot(tabla_resultado_P.index[-5:], predictions, label='Predicciones', color='green')
plt.xlabel('Year')
plt.ylabel('3P%')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18488/2103565342.py in <module>
#       8 # Supongamos que df es tu DataFrame con las columnas 'Años' y 'PorcentajeTriples'
#       9 # Asegúrate de tener un índice temporal para trabajar con series temporales
# ---> 10 tabla_resultado_P['Year'] = pd.to_datetime(tabla_resultado_P.index, format='%Y')
#      11 tabla_resultado_P.set_index('Year', inplace=True)
#      12
#
# c:\Users\Marc\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1057             result = _convert_and_box_cache(arg, cache_array, name=arg.name)
#    1058         else:
# -> 1059             result = convert_listlike(arg, format, name=arg.name)
#    1060     elif is_list_like(arg):
#    1061         try:
#
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

# Supongamos que df es tu DataFrame con las columnas 'Años' y 'PorcentajeTriples'
# Asegúrate de tener un índice temporal para trabajar con series temporales
tabla_resultado_P['Year'] = pd.to_datetime(tabla_resultado_P.index, format='%Y')
tabla_resultado_P.set_index('Year', inplace=True)

# Normalizar los datos
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(tabla_resultado_P[['3P%']])

# Crear conjuntos de entrenamiento y prueba
train_data = scaled_data[:-5]  # Tomar todos menos los últimos 5 años
test_data = scaled_data[-5:]   # Tomar los últimos 5 años para la evaluación

# Función para preparar los datos en secuencias para LSTM
def create_sequences(data, seq_length):
    sequences = []
    targets = []
    for i in range(len(data) - seq_length):
        seq = data[i:i + seq_length]
        label = data[i + seq_length]
        sequences.append(seq)
        targets.append(label)
    return np.array(sequences), np.array(targets)

# Definir la longitud de la secuencia
sequence_length = 3  # Ajusta según sea necesario

# Crear secuencias para entrenamiento y prueba
X_train, y_train = create_sequences(train_data, sequence_length)
X_test, y_test = create_sequences(test_data, sequence_length)

# Crear el modelo LSTM
model = Sequential()
model.add(LSTM(50, activation='relu', input_shape=(sequence_length, 1)))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

# Reshape los datos para que coincidan con la entrada de LSTM [samples, time steps, features]
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

# Entrenar el modelo
model.fit(X_train, y_train, epochs=100, verbose=1)

# Extender el conjunto de datos para los próximos 5 años
future_years = pd.date_range(tabla_resultado_P.index[-1] + pd.DateOffset(years=1), periods=5, freq='Y')

# Normalizar los datos de prueba extendidos
scaled_future_data = scaler.transform(tabla_resultado_P.loc[future_years][['3P%']])
X_future, y_future = create_sequences(scaled_future_data, sequence_length)

# Reshape los datos para que coincidan con la entrada de LSTM [samples, time steps, features]
X_future = X_future.reshape((X_future.shape[0], X_future.shape[1], 1))

# Realizar predicciones para los próximos 5 años
future_predictions = model.predict(X_future)

# Desnormalizar las predicciones
future_predictions = scaler.inverse_transform(future_predictions)

# Crear un rango de años para las predicciones futuras
years_future = future_years.year

# Graficar resultados
plt.plot(tabla_resultado_P.index[-5:], tabla_resultado_P['3P%'][-5:], label='Datos de prueba', color='orange')
plt.plot(years_future, future_predictions, label='Predicciones futuras', color='green')
plt.xlabel('Year')
plt.ylabel('3P%')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 2/2 [==============================] - 1s 2ms/step - loss: 0.0710
# Epoch 2/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0670
# Epoch 3/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0640
# Epoch 4/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0605
# Epoch 5/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0574
# Epoch 6/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0541
# Epoch 7/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0516
# Epoch 8/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0487
# Epoch 9/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0461
# Epoch 10/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0438
# Epoch 11/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0417
# Epoch 12/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0395
# ...
